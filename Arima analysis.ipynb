# %%
# -*- coding: utf-8 -*-

#경로 설정 
import os
from os import chdir #디렉토리 변경을 위한 라이브러리 호출 
chdir('C:\\Users\\welcome3\\Documents') #디렉토리 변경
os.getcwd() # 현재 디렉토리 위치
#s.listdir('.') # 모든 파일과 폴더명이 나타남
# Out:
# 'C:\\Users\\welcome3\\Documents'

# %%
# Arima with Python 
#https://byeongkijeong.github.io/ARIMA-with-Python/ 

import numpy as np 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from datetime import datetime

#from pandas.core import datetools 

df = pd.read_csv('timeline-data-20180405.csv', header=0, index_col=0, squeeze=True)
#print(df) #데이터 테이블 전체 프린트
#print(type(df)) #데이터 타입 알아보기 

def parser(x):
    return datetime.strptime("2018-03-31", "%Y-%m-%d")

#print(df.head())

# 정제해서 새 데이터 
series = df[df.columns[0:1]] # Remember, Python is 0-offset! The "3rd" entry is at slot 2.

fig, ax = plt.subplots(1)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax.bar(series, df['visitors'], width=25, align='center')
ax.xaxis_date()

#series.plot()
#print(series.head())
#plot_acf(series)
#plot_pacf(series)
#pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-60a54f44e658> in <module>()
#      27 fig, ax = plt.subplots(1)
#      28 ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
# ---> 29 ax.bar(series, df['visitors'], width=25, align='center')
#      30 ax.xaxis_date()
#      31
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
#    2083                 edgecolor=e,
#    2084                 linewidth=lw,
# ...

# %%
# 레이아웃 향상하기 

#plt.figure(figsize=(20,10))
#plt.plot(df2.dataFor, df2.total, linewidth=5)
#plt.plot(df2.dataFor, df2.total, '*', markersize=20, color='red')
#plt.xticks(fontsize=20, fontweight='bold',rotation=90)
#plt.yticks(fontsize=20, fontweight='bold')
#plt.xlabel('Dates',fontsize=20, fontweight='bold')
#plt.ylabel('Total Count',fontsize=20, fontweight='bold')
#plt.title('Counts per time',fontsize=20, fontweight='bold')
#plt.tight_layout()

# %%
plot_acf(series)
plot_pacf(series)
plt.show()

# %%
diff_1=series.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

times = pd.date_range('2015-10-06', periods=500, freq='10min')

fig, ax = plt.subplots(1)
fig.autofmt_xdate()
plt.plot(times, range(times.size))

xfmt = mdates.DateFormatter('%d-%m-%y %H:%M')
ax.xaxis.set_major_formatter(xfmt)

plt.show()
