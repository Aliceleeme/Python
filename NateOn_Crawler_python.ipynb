# %% [markdown]
# 네이트온 크롤러
# ======
#
# * 출처는 코드 안에 있습니다
# * 네이트온을 크롤링하는 과정에서 원활한 크롤링을 위해, 업데이트 된 UI 부분에 해당하는 xpath 및 일부 코드만을 편집하였습니다

# %%
# I editied several xpath to make web crawler for Nateon 

from selenium import webdriver
import requests
from bs4 import BeautifulSoup

#https://beomi.github.io/2017/02/27/HowToMakeWebCrawler-With-Selenium/

def recommend(url):
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml')
    recommend_list = soup.select('.btnwrap .count')
    print("댓글수 :", soup.select('.cmt_tit .num')[0].text)
    print("추천 :", recommend_list[0].text)
    print("반대 :", recommend_list[1].text)


#Search keyword
keyword = input("검색어를 입력하십시오: ")
binary= '/Users/jihye/Documents/chromedriver_mac64/chromedriver'
driver = webdriver.Chrome(binary)
driver.get('http://pann.nate.com/search/talk?q='+keyword)
driver.find_element_by_xpath("""//*[@id="GnbWrap"]/div[2]/a""").click()
driver.find_element_by_name("ID").send_keys("nateon_id")       #접속하려는 페이지 아이디
driver.find_element_by_name("PASSWD").send_keys("nateon_passcode")          #접속하려는 페이지 패스워드
driver.find_element_by_xpath('//*[@id="tab_cont1"]/div/input').click()
 
for i in range(1,3):
    print("Page"+str(i))
    print("\n")
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    subject_list = soup.select('.subject')
    driver.find_element_by_xpath('//*[@id="container"]/div[2]/div[1]/div[4]/a['+str(i)+']').click()
    for idx, subject in enumerate(subject_list, 1):
        print(idx, subject.text.strip(),subject['href'])
        recommend(subject['href'])
    print("\n")

# %%
#selenium을 통한 네이트판 게시물 타이틀과 댓글 가져오기 
#원본코드: http://blog.naver.com/nike_review/221050227966

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

binary= '/Users/jihye/Documents/chromedriver_mac64/chromedriver'
driver=webdriver.Chrome(binary)

driver.get('http://pann.nate.com/talk/c20011')
driver.find_element_by_xpath("""//*[@id="GnbWrap"]/div[2]/a""").click()
driver.find_element_by_name("ID").send_keys("alice0428_@nate.com")       #접속하려는 페이지 아이디
driver.find_element_by_name("PASSWD").send_keys("epikhigh2013")          #접속하려는 페이지 패스워드
driver.find_element_by_xpath("""//*[@id="tab_cont1"]/div/input""").click()

def search_pann(url):
        html = requests.get(url).text
        soup = BeautifulSoup(html,'html.parser')
        reply_list = soup.select('.usertxt')
        if len(reply_list) == 0:
            print("댓글이 없습니다")
        else:
            try:
                print("베스트 1위 ㄴ댓글 :", reply_list[0].text.strip())
                print("베스트 2위 댓글 :", reply_list[1].text.strip())
                print("베스트 3위 댓글 :", reply_list[2].text.strip())
            except:
                pass

for i in range(1,11):
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    tag_list = soup.select('.subject > a')
    #driver.find_element_by_xpath('//*[@id="searchDiv"]/div[1]/div/a['+str(i)+']').click()
    driver.find_element_by_xpath("//div[@id='searchDiv']/div[@class='posting_wrap']")   
    #참고코드: https://wkdtjsgur100.github.io/selenium-xpath/
    for idx, a_tag in enumerate(tag_list,1):
        print("\n")
        print(idx, a_tag.text.strip())
        search_pann(a_tag['href'])
    import requests
# Out:
# 1 사랑과 현실 그리고 이별
# 댓글이 없습니다
#
#
# 2 재수없는놈아
# 댓글이 없습니다
#
#
# 3 저같은분 계신가요ㅠㅠ?
# 댓글이 없습니다
#
#
# 4 이별후 2개월뒤 전남친생일 연락
# 댓글이 없습니다
#
#
# 5 은주야 정말 사랑했다
# 베스트 1위 ㄴ댓글 : 힘내세요..ㅠㅜㅠ근데 환승이별이면 돌아올지는 몰라도 재회한다하더라도 행복할까요..
# 베스트 2위 댓글 : 너무 힘들다
#
#
# 6 회피형남자랑 오늘 헤어졌어요
# 베스트 1위 ㄴ댓글 : 이건 회피형인간이 아니라 그냥 쓰레기인듯~
# 베스트 2위 댓글 : 잘헤어지셨어요 파이팅!!! 우리 더 좋은 사람 만날 수 있을거에요
#
#
# 7 상대방이 잡으면
# 베스트 1위 ㄴ댓글 : 잡아서 재회한 경험많은데 어쩔땐 잡아주길 바랄때도있어요 속마음은 헤어지기 싫었던거조
#
#
# 8 진짜좋아했어도 헤어지고 한번...
# 베스트 1위 ㄴ댓글 : 미래를 함께 할여자가 아니란걸 알면 그렇게되더라
# 괜히 만났다가 또 성가신일 생길수도있고하니..
# 베스트 2위 댓글 : 미련생길까바 그럴수도있고.. 정말 보기싫어서 그럴수도있고..
# 베스트 3위 댓글 : 네
#
#
# 9 재회후 같은이유로 안헤어져도
# 베스트 1위 ㄴ댓글 : 조금더성장하는계기가됐기를
#
#
# 10 다시 금요일이네
# 베스트 1위 ㄴ댓글 : 내가 생각하는 너였으면 좋겠다..
# 베스트 2위 댓글 : 난6개월쯤부터내패턴찾앗음요
# 베스트 3위 댓글 : 그땐 재밌는 남자 만나서 신나게 떠들면 최고인뎅
#
#
# 11 남자는 새여친 생기면 정말 ...
# 베스트 1위 ㄴ댓글 : 팩트는
# 새로만나는 사람이 글쓴이보다 빠질게없으면 안나고
# 새로만나는 사람이 글쓴이보다 못하거나하면 나겠죠?
# 베스트 2위 댓글 : 그당시는남자든여자든 잊지
# 베스트 3위 댓글 : 남자든 여자든 다 그럼
#
#
# 12 감정의 배설
# 베스트 1위 ㄴ댓글 : 저도 같은마음이에요 너무 억울해서 분노를 참기가 정말
# 힘드네요ᆞ
# 베스트 2위 댓글 : 뭔짓거릴하려고
#
#
# 13 나에게 책임이 있는건가요
# 베스트 1위 ㄴ댓글 : 스스로도한심하다그러니말다했지 스스로도빛나는사람이라생각나게가꾸면 남자들을니가고르고잇을걸
#
#
# 14 첫사랑
# 댓글이 없습니다
#
#
# 15 술만 쳐마시면 연락오는 강아지
# 베스트 1위 ㄴ댓글 : 공감 지 필요할땐 연락하다가 이대로 계속 연락하나보다 하고 연락하면 뚝 잠수,,,,,,,,,,,,
# 또 연락하다 또 잠수 ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, 양치기 소년의 결말을 모르나보죠 머
#
#
# 16 유종의 미가 얼마나 중요하냐면 말이다
# 댓글이 없습니다
#
#
# 17 차인지 1달
# 댓글이 없습니다
#
#
# 18 헤어지고 마음은 안좋지만 다...
# 베스트 1위 ㄴ댓글 : 저도 님처럼 연애하는 내내 헤어질까 고민을 달고 있다가 상대방이 헤어지자 했고 알겠다 하고 연락 안하고 있어요.. 헤어진지 10일정도 되니까 연락하고싶어지고 그러네요 9일동안은 잘 헤어진거같고 생각이 문득 들면 우울하고 그랬는데..
# 베스트 2위 댓글 : 그리움이 시간지나면 무뎌져요. 오히려 미련있어서 연락하고 그러는 감정이 더 힘드니 오히려 잘됐다생각하세요
# 베스트 3위 댓글 : 서로 상대적일거에요. 서로 좋았는데도 힘들었다면 상대도 충분히 힘들었을테니 연락 기다리지 않을 꺼에요 괜한 걱정 하시는거 같네요
#
#
# 19 한번 붙잡으면
# 베스트 1위 ㄴ댓글 : 한번정돈 괜찮을듯 그이상넘어가면 추해지는거지
# 베스트 2위 댓글 : 붙잡는게 왜 찌질한지 이해가 안가네요
# 서로 심하게 잘못한게 없으면 잡을수 있지요
# 베스트 3위 댓글 : 어떻게 기억되느냐가 중요한가요?? 그사람이 떠나는게 싫다면 찌질해보이건 어쩌건 잡고싶을거같은데 헤어지면 그사람이 날 어떻게여기든 무슨상관일까요 이제남인데
#
#
# 20 현실적으론 안되는거 아는데 몇달뒤에...
# 댓글이 없습니다
#
#
# 21 후회는 없다
# 댓글이 없습니다
#
#
# 22 권태기때 헤어진 커플
# 댓글이 없습니다
#
#
# 23 카톡 프로필사진
# 베스트 1위 ㄴ댓글 : 헤어진지 얼마나 됐어요?
#
#
# 24 바람피고 나서도
# 베스트 1위 ㄴ댓글 : 이곳 저곳 기웃대는새끼치고 정신병아닌놈 없습니다 평생그러고 살놈들임
# 오죽 사랑을 못받고살았음 저럴까 생각들죠... 에이즈나 걸려라 ㅋ
# 베스트 2위 댓글 : 아 나도 열받네 쓰레기들 넘 많다 이기적인 ㅆㄲ들 바람피는것들은 거짓말도 잘 하고 병이라서 한여자한테 정착을 못함 좋은경험 했다 생각하고 좋은사람 만나자
# 베스트 3위 댓글 : 저는 환승당한 남잔데요..정말 뻔뻔하기 그지없더라구요..하 생각만하면 열받네요ㅠㅠ
#
#
# 25 카카오톡
# 베스트 1위 ㄴ댓글 : 사랑의 반대는 무관심이죠.
# 사람마다 다르고 그 답은 상대방만 알겠지만 차단을
# 했단건 싫은거든 힘든거든 뭔가 감정이 있는거겠죠?
# 다만 지금은 다가갈 타이밍이 아니라는건 확실하네요
#
#
# 26 우린 참 잘한거 같아
# 베스트 1위 ㄴ댓글 : 찬 사람이니까 여유있게 저러지
# 베스트 2위 댓글 : 행복해라 .....
# 베스트 3위 댓글 : 그 사람이 괜찮은지는 어떻게 아나요?
#
#
# 27 찬 남자들은 매달리던 여자가
# 댓글이 없습니다
#
#
# 28 걔 기억 속에서 쉽게 잊혀질거 생각...
# 댓글이 없습니다
#
#
# 29 술김에 연락하게 될까봐 술을...
# 베스트 1위 ㄴ댓글 : 뭐 어때요.. 전화해서 욕이라도 한바가지하면되죠. 지난 간 사랑때문에 지금 자신을 구속하지마세요
# 베스트 2위 댓글 : 정 그러시면 저처럼 그냥 번호를 바꿔보세요. 외우셨다면 효과적이지 않겠지만 번호 안외운 저는 되게 효과적인 방법이더라구요
# 베스트 3위 댓글 : 저도 그래요.. 술김에 전화하고 싶은 생각도 들지만... 그게 더 상대가 싫어할거같다는 생각이 문득 드는 순간... 친구들과의 술자리 못 가겠더라구요
#
#
# 30 여자분들중에
# 베스트 1위 ㄴ댓글 : 지극히 갠적인 생각인데...내가 잘못한거면 그전에 연락하겠지만 남자쪽이 문제있다면 10일정도면 정리단계들어갑니다
# 베스트 2위 댓글 : 찼는지 차였는지에 따라 다르겠죠
